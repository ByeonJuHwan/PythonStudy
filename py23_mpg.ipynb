# %% [markdown]
# <a href="https://colab.research.google.com/github/ByeonJuHwan/PythonStudy/blob/main/py23_mpg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # mpg (Mile Per Gallon) 데이터 셋
#
# * mpg 데이터 셋을 로드하고 탐색.
# * mpg ~ displacement scatter plot
# * 2x2 subplot을 생성. scatter plot.
#     * mpg ~ cylinders
#     * mpg ~ horsepower
#     * mpg ~ weight
#     * mpg ~ acceleration
# * cylinders별 mpg 평균 막대 그래프
# * cylinders별 mpg box plot
# * origin별, cylinders별 mpg box plot
# * origin별, cylinders별 mpg 평균 막대 그래프

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpg = sns.load_dataset('mpg')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# mpg DataFrame
#
# * mpg : 자동차연비
# * cylinders : 자동차 엔진의 실린더 개수.
# * displacement : 배기량.

# %%
sns.scatterplot(data=mpg, x="displacement", y="mpg",alpha=0.5)
plt.show()

# %%
# mpg ~ displacement + origin
sns.scatterplot(data=mpg, x='displacement', y='mpg',hue='origin')
plt.show()

# %%
fig, ax = fig, ax = plt.subplots(ncols=2,nrows=2 ,figsize=(11,7))

sns.scatterplot(data=mpg, x='cylinders',y='mpg',ax=ax[0][0])
sns.scatterplot(data=mpg, x='horsepower',y='mpg',ax=ax[0][1])
sns.scatterplot(data=mpg, x='weight',y='mpg',ax=ax[1][0])
sns.scatterplot(data=mpg, x='acceleration',y='mpg',ax=ax[1][1])
plt.show()

# %%
sns.barplot(data=mpg, x='cylinders',y='mpg')
plt.show()

# %%
sns.boxplot(data=mpg, x='cylinders',y='mpg')
plt.show()

# %%
#origin별, cylinders별 mpg box plot

sns.boxplot(data=mpg,x='origin',y='mpg',hue='cylinders') 
plt.show()

# %%
sns.catplot(data=mpg, col ='origin',x ='cylinders', y='mpg', kind='box')
plt.show()

# %%
#origin별, cylinders별 mpg 평균 막대 그래프
sns.catplot(data=mpg,col='origin',y='mpg',x='cylinders',kind='bar') 
plt.show()
